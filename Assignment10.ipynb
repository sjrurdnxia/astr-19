# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
mu, kappa = 0.0, 4.0 # mean and dispersion
random = np.random.vonmises(mu, kappa, 1000)

# %%
plt.hist(random, bins=100)
plt.xlabel('value')
plt.ylabel('frequency')
plt.savefig('random.pdf')
plt.show()
